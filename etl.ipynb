# %%
import pandas as pd
import numpy as np
import re

# %%
diabetic_data = pd.read_csv('data/diabetic_data.csv')
diabetic_data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetic_data.sample(25)
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 75541      226748574    102079377        Caucasian    Male  [60-70)
# 65835      183770118     44127414        Caucasian  Female  [50-60)
# 28336       92864526      6866964                ?    Male  [60-70)
# 83134      259861338     58474134        Caucasian  Female  [80-90)
# 47583      146111946     82666917        Caucasian    Male   [0-10)
# 52315      154994880      3447360        Caucasian    Male  [70-80)
# 62869      174988638     38989323  AfricanAmerican    Male  [80-90)
# 12843       51834210     75627180  AfricanAmerican  Female  [60-70)
# 5613        28961514    108341001        Caucasian    Male  [70-80)
# 26681       87752796     24105465        Caucasian  Female  [80-90)
# 57351      163621566    110819016        Caucasian  Female  [50-60)
# 52161      154726764     24868170  AfricanAmerican    Male  [50-60)
# 57290      163592412     84535641        Caucasian  Female  [30-40)
# 74952      223971762     59353344        Caucasian    Male  [60-70)
# 79471      243973782    102252987        Caucasian    Male  [80-90)
# 52461      155231958     24610455  AfricanAmerican    Male  [70-80)
# 14564       56627784     19039149  AfricanAmerican  Female  [70-80)
# 100297     424296218     44636130  AfricanAmerican  Female  [50-60)
# 80210      247030854     95157675        Caucasian  Female  [30-40)
# 42751      131844960     41108508        Caucasian  Female  [70-80)
# 70739      203553108     73051353        Caucasian  Female  [60-70)
# 69071      195717996     29444904        Caucasian  Female  [50-60)
# 98971      407846816     95178258        Caucasian    Male  [60-70)
# 76031      229078734     89062020  AfricanAmerican  Female  [50-60)
# 60097      168536400     65686428         Hispanic    Male  [70-80)
#
#            weight  admission_type_id  discharge_disposition_id  \
# 75541   [100-125)                  3                         1
# 65835           ?                  1                         1
# 28336           ?                  2                         1
# 83134           ?                  1                         3
# 47583           ?                  2                         1
# 52315           ?                  6                         1
# 62869           ?                  1                         4
# 12843           ?                  1                         1
# 5613            ?                  1                         1
# 26681           ?                  1                        14
# 57351           ?                  1                         1
# 52161           ?                  3                         1
# 57290           ?                  1                         6
# 74952           ?                  3                         1
# 79471           ?                  1                         3
# 52461           ?                  1                         1
# 14564           ?                  1                         1
# 100297          ?                  1                        13
# 80210           ?                  1                         1
# 42751           ?                  1                         1
# 70739           ?                  1                         1
# 69071           ?                  3                         6
# 98971           ?                  1                         1
# 76031           ?                  1                         7
# 60097           ?                  5                         6
#
#         admission_source_id  time_in_hospital  ... citoglipton insulin  \
# 75541                     1                 1  ...          No      No
# 65835                     7                 3  ...          No      No
# 28336                     1                 3  ...          No  Steady
# 83134                     7                 7  ...          No  Steady
# 47583                     1                 6  ...          No      Up
# 52315                    17                 1  ...          No      No
# 62869                     2                 9  ...          No      No
# 12843                     7                 4  ...          No      No
# 5613                      7                 3  ...          No  Steady
# 26681                    17                 8  ...          No      Up
# 57351                     1                 4  ...          No  Steady
# 52161                     1                 2  ...          No      No
# 57290                     7                 6  ...          No      No
# 74952                     1                 1  ...          No      No
# 79471                     7                 3  ...          No  Steady
# 52461                     7                 5  ...          No      Up
# 14564                     7                 4  ...          No  Steady
# 100297                    7                 4  ...          No      No
# 80210                     7                 2  ...          No    Down
# 42751                     7                 4  ...          No  Steady
# 70739                     7                 6  ...          No  Steady
# 69071                     1                 8  ...          No  Steady
# 98971                     7                 2  ...          No  Steady
# 76031                     7                 1  ...          No      No
# 60097                     1                 1  ...          No      Up
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 75541                    No                   No                        No
# 65835                    No                   No                        No
# 28336                    No                   No                        No
# 83134                    No                   No                        No
# 47583                    No                   No                        No
# 52315                    No                   No                        No
# 62869                    No                   No                        No
# 12843                    No                   No                        No
# 5613                     No                   No                        No
# 26681                    No                   No                        No
# 57351                    No                   No                        No
# 52161                    No                   No                        No
# 57290                    No                   No                        No
# 74952                    No                   No                        No
# 79471                    No                   No                        No
# 52461                    No                   No                        No
# 14564                    No                   No                        No
# 100297                   No                   No                        No
# 80210                    No                   No                        No
# 42751                    No                   No                        No
# 70739                    No                   No                        No
# 69071                    No                   No                        No
# 98971                    No                   No                        No
# 76031                    No                   No                        No
# 60097                    No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 75541                        No                      No      No         Yes
# 65835                        No                      No      Ch         Yes
# 28336                        No                      No      No         Yes
# 83134                        No                      No      No         Yes
# 47583                        No                      No      Ch         Yes
# 52315                        No                      No      No         Yes
# 62869                        No                      No      No          No
# 12843                        No                      No      No         Yes
# 5613                         No                      No      No         Yes
# 26681                        No                      No      Ch         Yes
# 57351                        No                      No      Ch         Yes
# 52161                        No                      No      No          No
# 57290                        No                      No      No          No
# 74952                        No                      No      No          No
# 79471                        No                      No      Ch         Yes
# 52461                        No                      No      Ch         Yes
# 14564                        No                      No      Ch         Yes
# 100297                       No                      No      No         Yes
# 80210                        No                      No      Ch         Yes
# 42751                        No                      No      Ch         Yes
# 70739                        No                      No      Ch         Yes
# 69071                        No                      No      Ch         Yes
# 98971                        No                      No      Ch         Yes
# 76031                        No                      No      No         Yes
# 60097                        No                      No      Ch         Yes
#
#        readmitted
# 75541         <30
# 65835         >30
# 28336          NO
# 83134          NO
# 47583         >30
# 52315          NO
# 62869          NO
# 12843         >30
# 5613          <30
# 26681          NO
# 57351         >30
# 52161          NO
# 57290         >30
# 74952          NO
# 79471          NO
# 52461          NO
# 14564          NO
# 100297         NO
# 80210         >30
# 42751          NO
# 70739         >30
# 69071          NO
# 98971         >30
# 76031          NO
# 60097         <30
#
# [25 rows x 50 columns]

# %%
# weight has to many np.nan
# payer_code is not related to diabetic data
drop_columns = ['weight', 'payer_code']

# %%
dropped_diabetic_data = diabetic_data.drop(drop_columns, axis=1)
dropped_diabetic_data.sample(25)
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 32481      103517430     78510465        Caucasian  Female  [50-60)
# 75391      225883482     28770885        Caucasian    Male  [60-70)
# 78129      238248402     65029725        Caucasian  Female  [20-30)
# 90978      303152948     42405741        Caucasian  Female  [60-70)
# 37328      115613730     68268114        Caucasian    Male  [70-80)
# 97744      392538788    138719228        Caucasian    Male  [70-80)
# 74163      220619442     96421806        Caucasian    Male  [80-90)
# 2523        16416120      1123560        Caucasian  Female  [40-50)
# 69164      196213362     59583888            Other    Male  [30-40)
# 61467      171586554    102482199        Caucasian    Male  [70-80)
# 8570        38519586      2120220  AfricanAmerican    Male  [60-70)
# 22421       77295018     55425870        Caucasian    Male  [60-70)
# 109          1668252     76159881        Caucasian  Female  [50-60)
# 27737       90873714     28108152                ?  Female  [80-90)
# 35092      109112274      5545998  AfricanAmerican    Male  [50-60)
# 57277      163580814     23908356  AfricanAmerican    Male  [50-60)
# 77592      235866030     70617762                ?    Male  [60-70)
# 39197      122041482     73497915        Caucasian  Female  [80-90)
# 4052        23703228      3344832        Caucasian    Male  [30-40)
# 100451     426093662    180999059            Other  Female  [60-70)
# 3665        22195080      2086038         Hispanic  Female  [70-80)
# 3926        23176602      2585367        Caucasian  Female  [80-90)
# 23122       79133886     87820137        Caucasian    Male  [50-60)
# 27499       90089886     81632997        Caucasian    Male  [50-60)
# 50890      152410128     58796532        Caucasian  Female  [40-50)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 32481                   1                         1                    7
# 75391                   2                         6                    1
# 78129                   2                         1                    1
# 90978                   3                         3                    1
# 37328                   6                         1                    1
# 97744                   1                         6                    7
# 74163                   2                         3                    7
# 2523                    1                         1                    7
# 69164                   1                         1                    7
# 61467                   2                         1                    7
# 8570                    1                         1                    7
# 22421                   1                         5                    7
# 109                     3                         1                    2
# 27737                   5                         6                   17
# 35092                   2                         1                    1
# 57277                   1                         1                    7
# 77592                   2                         6                    1
# 39197                   3                         3                    4
# 4052                    2                         1                    4
# 100451                  1                         1                    7
# 3665                    1                         1                    7
# 3926                    1                         3                    7
# 23122                   1                         4                    7
# 27499                   6                         1                   17
# 50890                   1                         3                    7
#
#         time_in_hospital                  medical_specialty  ...  citoglipton  \
# 32481                  1                   InternalMedicine  ...           No
# 75391                  4                                  ?  ...           No
# 78129                  3                                  ?  ...           No
# 90978                  5                         Nephrology  ...           No
# 37328                  6                                  ?  ...           No
# 97744                  4                                  ?  ...           No
# 74163                  1             Family/GeneralPractice  ...           No
# 2523                   6                   InternalMedicine  ...           No
# 69164                  1                                  ?  ...           No
# 61467                  1                   Emergency/Trauma  ...           No
# 8570                   2                    Surgery-General  ...           No
# 22421                  2             Family/GeneralPractice  ...           No
# 109                    1                                  ?  ...           No
# 27737                  1             Family/GeneralPractice  ...           No
# 35092                  2                            Urology  ...           No
# 57277                  3                   InternalMedicine  ...           No
# 77592                  6                                  ?  ...           No
# 39197                 14                                  ?  ...           No
# 4052                   7  PhysicalMedicineandRehabilitation  ...           No
# 100451                 2                                  ?  ...           No
# 3665                   2             Family/GeneralPractice  ...           No
# 3926                   3                   InternalMedicine  ...           No
# 23122                  5                   InternalMedicine  ...           No
# 27499                  1                         Cardiology  ...           No
# 50890                  9                                  ?  ...           No
#
#         insulin  glyburide-metformin  glipizide-metformin  \
# 32481      Down                   No                   No
# 75391    Steady                   No                   No
# 78129    Steady                   No                   No
# 90978      Down                   No                   No
# 37328        No                   No                   No
# 97744      Down                   No                   No
# 74163        No                   No                   No
# 2523         Up                   No                   No
# 69164      Down                   No                   No
# 61467      Down                   No                   No
# 8570         No                   No                   No
# 22421    Steady                   No                   No
# 109      Steady                   No                   No
# 27737        No                   No                   No
# 35092    Steady                   No                   No
# 57277      Down                   No                   No
# 77592        Up                   No                   No
# 39197        No                   No                   No
# 4052       Down                   No                   No
# 100451       No                   No                   No
# 3665         No                   No                   No
# 3926         No                   No                   No
# 23122        No                   No                   No
# 27499        No                   No                   No
# 50890        No                   No                   No
#
#         glimepiride-pioglitazone  metformin-rosiglitazone  \
# 32481                         No                       No
# 75391                         No                       No
# 78129                         No                       No
# 90978                         No                       No
# 37328                         No                       No
# 97744                         No                       No
# 74163                         No                       No
# 2523                          No                       No
# 69164                         No                       No
# 61467                         No                       No
# 8570                          No                       No
# 22421                         No                       No
# 109                           No                       No
# 27737                         No                       No
# 35092                         No                       No
# 57277                         No                       No
# 77592                         No                       No
# 39197                         No                       No
# 4052                          No                       No
# 100451                        No                       No
# 3665                          No                       No
# 3926                          No                       No
# 23122                         No                       No
# 27499                         No                       No
# 50890                         No                       No
#
#        metformin-pioglitazone change diabetesMed  readmitted
# 32481                      No     Ch         Yes         >30
# 75391                      No     Ch         Yes         >30
# 78129                      No     No         Yes          NO
# 90978                      No     Ch         Yes         >30
# 37328                      No     No         Yes         >30
# 97744                      No     Ch         Yes          NO
# 74163                      No     No          No         >30
# 2523                       No     Ch         Yes          NO
# 69164                      No     Ch         Yes         >30
# 61467                      No     Ch         Yes          NO
# 8570                       No     No          No         >30
# 22421                      No     No         Yes          NO
# 109                        No     No         Yes         >30
# 27737                      No     Ch         Yes          NO
# 35092                      No     Ch         Yes          NO
# 57277                      No     Ch         Yes         <30
# 77592                      No     Ch         Yes         >30
# 39197                      No     No          No         >30
# 4052                       No     Ch         Yes          NO
# 100451                     No     No          No         >30
# 3665                       No     No         Yes         >30
# 3926                       No     Ch         Yes          NO
# 23122                      No     Ch         Yes          NO
# 27499                      No     No         Yes          NO
# 50890                      No     No          No         >30
#
# [25 rows x 48 columns]

# %%
# there are some values set as '?'
# will replace them with NAN to be consistent with dataset
# dropped_diabetic_data.replace(to_replace='?', value=np.nan, inplace=True)

# %%
dropped_diabetic_data['metformin'].value_counts()
# Down: -1
# No: 0
# Up: 1
# Steady: 2
# Out:
# No        81778
# Steady    18346
# Up         1067
# Down        575
# Name: metformin, dtype: int64

# %%
dropped_diabetic_data['repaglinide'].value_counts()
# Out:
# No        100227
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64

# %%
dropped_diabetic_data['nateglinide'].value_counts()
# Out:
# No        101063
# Steady       668
# Up            24
# Down          11
# Name: nateglinide, dtype: int64

# %%
dropped_diabetic_data['metformin'] = dropped_diabetic_data['metformin'].replace({'Down': -1, 'No': 0, 'Up': 1, 'Steady': 2})
dropped_diabetic_data['repaglinide'] = dropped_diabetic_data['repaglinide'].replace({'Down': -1, 'No': 0, 'Up': 1, 'Steady': 2})
dropped_diabetic_data['nateglinide'] = dropped_diabetic_data['nateglinide'].replace({'Down': -1, 'No': 0, 'Up': 1, 'Steady': 2})

# %%
dropped_diabetic_data[['metformin','repaglinide','nateglinide']].sample(25)
# Out:
#         metformin  repaglinide  nateglinide
# 60683           0            0            0
# 75006           0            0            0
# 37035           2            0            0
# 80171           0            0            0
# 18978           0            0            0
# 29803           0            0            0
# 24783           0            0            0
# 60225           0            0            0
# 77257           0            0            0
# 100775          0            0            0
# 25627           0            0            0
# 26100           0            0            0
# 62403           0            0            0
# 42699           0            0            0
# 61529           0            0            0
# 53425           0            0            0
# 39478           2            0            0
# 4802            2            0            0
# 50025           0            0            0
# 59034          -1            0            0
# 32418           0            0            0
# 37439           0            0            0
# 99082           0            0            0
# 1694            0            0            0
# 60812           0            0            0

# %%
dropped_diabetic_data[['metformin','repaglinide','nateglinide']].dtypes
# Out:
# metformin      int64
# repaglinide    int64
# nateglinide    int64
# dtype: object

# %%
dropped_diabetic_data['change'].value_counts()
# No = 0
# Ch = 1
# Out:
# No    54755
# Ch    47011
# Name: change, dtype: int64

# %%
dropped_diabetic_data['change'] = dropped_diabetic_data['change'].replace({'No': 0, 'Ch': 1})

# %%
dropped_diabetic_data['diabetesMed'].value_counts()
# No = 0
# Yes = 1
# Out:
# Yes    78363
# No     23403
# Name: diabetesMed, dtype: int64

# %%
dropped_diabetic_data['diabetesMed'] = dropped_diabetic_data['diabetesMed'].replace({'No': 0, 'Yes': 1})

# %%
dropped_diabetic_data['max_glu_serum'].value_counts()
# 'None': 0, 
# 'Norm': 1, 
# '>200': 2, 
# '>300': 3
# Out:
# None    96420
# Norm     2597
# >200     1485
# >300     1264
# Name: max_glu_serum, dtype: int64

# %%
dropped_diabetic_data['max_glu_serum'] = dropped_diabetic_data['max_glu_serum'].replace({'None': 0, 'Norm': 1, '>200': 2, '>300': 3})

# %%
dropped_diabetic_data['A1Cresult'].value_counts()
# 'None': 0, 'Norm': 1, '>7': 2, '>8': 3
# Out:
# None    84748
# >8       8216
# Norm     4990
# >7       3812
# Name: A1Cresult, dtype: int64

# %%
dropped_diabetic_data['A1Cresult'] = dropped_diabetic_data['A1Cresult'].replace({'None': 0, 'Norm': 1, '>7': 2, '>8': 3})

# %%
dropped_diabetic_data['readmitted'].value_counts()
# NO = 0
# <30 = 1
# >30 = 2
# Out:
# NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64

# %%
dropped_diabetic_data['readmitted'] = dropped_diabetic_data['readmitted'].replace({'NO': 0, '<30': 1, '>30': 2})

# %%
diag = ['diag_1', 'diag_2', 'diag_3']
dropped_diabetic_data[diag].sample(25)
# Out:
#       diag_1  diag_2  diag_3
# 1870     414     411     428
# 45494    428     427     496
# 58401    491     438     438
# 412      820     285  250.01
# 13296    414     V45     250
# 2576     410     427     250
# 17555    786     780     414
# 57103    507     401     414
# 46403    153     196     280
# 83013    584  250.22     204
# 43301    250     276     560
# 29966    996     403     V45
# 81148    600     599  250.02
# 57538    434     401     250
# 30859    157     197     157
# 68700  250.4     V45     403
# 16942    427     293     250
# 41854    577     250     786
# 54869    486     491     428
# 64712  250.8     294     272
# 17396    427     428     425
# 79079    514     511     496
# 67335    414     427     424
# 47306    414     786     402
# 90229    531     532     285
